# %%
library("ibmWatsonStudioLib")
wslib <- access_project_or_space()
print("watsonlib loaded")
# Out:
# [1] "watsonlib loaded"

# %%
library(nnet)

# %%
#csv <- capture.output(write.csv(iris, row.names=FALSE), type="output")
#csv_raw <- charToRaw(paste0(csv, collapse='\n'))
#wslib$save_data("input.csv", csv_raw)

# %%
input_file <- Sys.getenv('input_file_name')

# %%
input_file <- gsub("\"", "", input_file)

# %%
print(input_file)
# Out:
# [1] "input.csv"

# %%
# read data
my_file <- wslib$load_data(input_file)
df <-  read.csv(text = rawToChar(my_file))
head(df)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
wslib$download_file("preprocess_data.R")
# Out:
# $file_name
# [1] "preprocess_data.R"
#
# $summary
# [1] "loaded data"   "saved to file"

# %%
source("preprocess_data.R")

# %%
df_processed <- preprocess_data(df, "Species")

# %%
head(df_processed)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         s
# 2 4.9          3.0         1.4          0.2         s
# 3 4.7          3.2         1.3          0.2         s
# 4 4.6          3.1         1.5          0.2         s
# 5 5.0          3.6         1.4          0.2         s
# 6 5.4          3.9         1.7          0.4         s

# %%
wslib$download_file("model.rds")
# Out:
# $file_name
# [1] "model.rds"
#
# $summary
# [1] "loaded data"   "saved to file"

# %%
load_model <- readRDS("model.rds")

# %%
load_model
# Out:
# a 4-2-3 network with 19 weights
# inputs: Sepal.L. Sepal.W. Petal.L. Petal.W.
# output(s): species
# options were - softmax modelling  decay=5e-04

# %%
colnames(df_processed) <- c('Sepal.L.','Sepal.W.','Petal.L.','Petal.W.','species')

# %%
final_predictions <- predict(load_model, df_processed[1:5,])

# %%
final_predictions
# Out:
#   c            s         v
# 1 0.0005185416 0.9994812 2.665095e-07
# 2 0.0005947104 0.9994050 3.002636e-07
# 3 0.0005419494 0.9994578 2.769472e-07
# 4 0.0006250306 0.9993747 3.135400e-07
# 5 0.0005134424 0.9994863 2.642277e-07

# %%
csv <- capture.output(write.csv(final_predictions, row.names=FALSE), type="output")
csv_raw <- charToRaw(paste0(csv, collapse='\n'))
# Out:
# $name
# [1] "output.csv"
#
# $asset_type
# [1] "data_asset"
#
# $asset_id
# [1] "8e6b8ca4-d38d-4238-b54f-1582d76e4bac"
#
# $attachment_id
# [1] "a8c80f8f-73f2-4513-86dc-306d29b1bf6a"
#
# $filepath
# [1] "output.csv"
#
# $data_size
# [1] 310
#
# $mime
# [1] "text/csv"
#
# $summary
# $summary[[1]]
# [1] "created file"
#
# $summary[[2]]
# [1] "created data asset"
#
# $summary[[3]]
# [1] "created attachment"

# %%
file_name <- paste0(strftime(Sys.time()), ".csv")
file_name <- gsub(":", "-", file_name)

# %%
wslib$save_data(file_name, csv_raw)
# Out:
# $name
# [1] "2021-08-17 20-24-19.csv"
#
# $asset_type
# [1] "data_asset"
#
# $asset_id
# [1] "ff3411f7-aacc-4e04-93dc-5cdc0e2c029e"
#
# $attachment_id
# [1] "cd373773-b967-4439-8bcd-39cb6fb754e2"
#
# $filepath
# [1] "2021-08-17 20-24-19.csv"
#
# $data_size
# [1] 310
#
# $mime
# [1] "text/csv"
#
# $summary
# $summary[[1]]
# [1] "created file"
#
# $summary[[2]]
# [1] "created data asset"
#
# $summary[[3]]
# [1] "created attachment"
